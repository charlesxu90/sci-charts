# %% [markdown]
# # Errorbar

# %% [markdown]
# ## Double variable errorbar

# %%
import matplotlib.pyplot as plt
import numpy as np
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

x = [2, 4, 6]
y = [4, 6, 3]

xerr = [0.5, 0.8, 1.1]
yerr = [1, 2, 1.5]

ax.errorbar(x, y, xerr=xerr, yerr=yerr, fmt='o', ecolor='k', 
            elinewidth=3, capsize=6, capthick=3, ms=10, mew=2, mfc='w', mec='k')

ax.set_ylim(0, 8)
ax.set_xlabel("Class")
ax.set_ylabel("Values")
plot_style_utils.save_for_pub(fig=fig, path="figures/errorbar_only_xyerr", include_vector=False)

# %% [markdown]
# ## Barplot + errorbar

# %%
import matplotlib.pyplot as plt
import numpy as np
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

x = [2, 4, 6]
y = [4, 6, 3]

xerr = [0.5, 0.8, 1.1]
yerr = [1, 2, 1.5]

ax.bar(x, y, yerr=yerr, ecolor='k', 
       error_kw=dict(elinewidth=3, capsize=6, capthick=3, ms=10, mew=2,))

ax.set_xlabel("Class")
ax.set_ylabel("Values")
plot_style_utils.save_for_pub(fig=fig, path="figures/errorbar_bar_yonly", include_vector=False)

# %% [markdown]
# # Dotplot

# %% [markdown]
# ## Common dotplot for few samples

# %%
import matplotlib.pyplot as plt
import numpy as np
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
data = [3, 4, 2, 5, 3, 4, 6, 7]  # Be cautious, the value shouldn't be too large

for value, count in zip(labels, data):
    ax.plot([value]*count, range(count), marker='o', ms=12, mew=2, mec='k', mfc=plot_style_utils.CAT_PALETTE[0], color='grey', linestyle='None')
ax.grid(True)
ax.set_xlabel("Class")
ax.set_ylabel("Values")
plot_style_utils.save_for_pub(fig=fig, path="figures/dotplot", include_vector=False)

# %% [markdown]
# ## Cleveland-style dot plot

# %%
import numpy as np
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

values = [3, 4, 2, 5, 3, 4, 6, 7]
labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
y = np.arange(len(labels))[::-1]

# add horizontal line
ax.plot(values[::-1], y, marker='o', ms=12, mec='k', linestyle='', markeredgewidth=2, color=plot_style_utils.CAT_PALETTE[0])
ax.yaxis.set_ticks(y)
ax.yaxis.set_ticklabels(labels)

ax.tick_params(axis='y', which='major', right='on', left='on', color='0.8')
ax.grid(True, color='0.9', )

ax.set_xlabel("Values")
ax.set_ylabel("Class")
plot_style_utils.save_for_pub(fig=fig, path="figures/horizontal_dotplot", include_vector=False)

# %% [markdown]
# ## Lollipop chart

# %%
import numpy as np
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

values = [3, 4, 2, 5, 3, 4, 6, 7]
labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
y = np.arange(len(labels))[::-1]

ax.hlines(y, 0, values[::-1], color=plot_style_utils.CAT_PALETTE[0], lw=2)
ax.plot(values[::-1], y, marker='o', ms=12, mec='k', linestyle='', markeredgewidth=2, color=plot_style_utils.CAT_PALETTE[0])
ax.yaxis.set_ticks(y)
ax.yaxis.set_ticklabels(labels)

ax.tick_params(axis='y', which='major', right='on', left='on', color='0.8')
ax.grid(True, color='0.9', )
ax.set_xlim(0, 8)

ax.set_xlabel("Values")
ax.set_ylabel("Class")
plot_style_utils.save_for_pub(fig=fig, path="figures/horizontal_dotplot", include_vector=False)

# %% [markdown]
# # Lineplot

# %%
import numpy as np
import seaborn as sns
import plot_style_utils

tips = sns.load_dataset("tips")

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

sns.pointplot(x="day", y="total_bill", data=tips, estimator=np.mean, 
              capsize=0.2, markersize=5, err_kws={'linewidth': 2}, #errorbar=None, 
              ax=ax, color=plot_style_utils.CAT_PALETTE[0])

ax.set_xlabel("Day")
ax.set_ylabel("Total Bill")
ax.set_ylim(13, 24)

plot_style_utils.save_for_pub(fig=fig, path="figures/line_pointplot", include_vector=False)

# %% [markdown]
# # Strip plot
# For individual value plot

# %%
import seaborn as sns
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

tips = sns.load_dataset("tips")
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, ax=ax, color='0.3', alpha=0.5, palette=plot_style_utils.CAT_PALETTE[:4], hue="day")

ax.set_xlabel("Time")
ax.set_ylabel("Total Bill")
ax.set_ylim(0, 50)

plot_style_utils.save_for_pub(fig=fig, path="figures/stripplot", include_vector=False)

# %% [markdown]
# # Barchart

# %% [markdown]
# ## Common barchart decending by value

# %%
import pandas as pd
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

name = ["A", "B", "C", "D", "E"]
value = [3, 4, 2, 5, 3]

df_data = pd.DataFrame({"name": name, "value": value})

df_data = df_data.sort_values(by="value", ascending=False)
ax.bar(df_data["name"], df_data["value"], color=plot_style_utils.CAT_PALETTE[0])
ax.bar_label(ax.bar(df_data["name"], df_data["value"], color=plot_style_utils.CAT_PALETTE[0]), fmt='%.1f', padding=3)

ax.grid(True, color='0.6', linestyle='--', linewidth=1)
ax.set_xlabel("Class")
ax.set_ylabel("Values")
ax.set_ylim(0, 6)
plot_style_utils.save_for_pub(fig=fig, path="figures/barplot", include_vector=False)

# %% [markdown]
# ## Common barchart -- label order

# %%
import pandas as pd
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

name = ["A", "B", "C", "D", "E"]
value = [3, 4, 2, 5, 3]

df_data = pd.DataFrame({"name": name, "value": value})

df_data = df_data.sort_values(by="name", ascending=True)
ax.bar(df_data["name"], df_data["value"], color=plot_style_utils.CAT_PALETTE[0])
ax.bar_label(ax.bar(df_data["name"], df_data["value"], color=plot_style_utils.CAT_PALETTE[0]), fmt='%.1f', padding=3)

ax.grid(True, color='0.6', linestyle='--', linewidth=1)
ax.set_xlabel("Class")
ax.set_ylabel("Values")
ax.set_ylim(0, 6)
plot_style_utils.save_for_pub(fig=fig, path="figures/barplot2", include_vector=False)

# %% [markdown]
# ## Barchart with errorbar

# %%
import pandas as pd
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

name = ["A", "B", "C", "D", "E"]
value = [3, 4, 2, 5, 3]
error = [0.3, 0.4, 0.2, 0.5, 0.3]

df_data = pd.DataFrame({"name": name, "value": value})

df_data = df_data.sort_values(by="value", ascending=False)
ax.bar(df_data["name"], df_data["value"], color=plot_style_utils.CAT_PALETTE[0], yerr=error, capsize=5, ecolor='k')

ax.grid(True, color='0.6', linestyle='--', linewidth=1)
ax.set_xlabel("Class")
ax.set_ylabel("Values")
ax.set_ylim(0, 6)
plot_style_utils.save_for_pub(fig=fig, path="figures/barplot_err", include_vector=False)

# %% [markdown]
# # Grouped barchart

# %%
import pandas as pd
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

labels = ['A', 'B', 'C', 'D', 'E']
type1 = [3, 4, 2, 5, 3]
type2 = [4, 3, 4, 6, 7]
type3 = [2, 5, 6, 3, 4]

x = np.arange(len(labels))  # the label locations

width = 0.25  # the width of the bars
ax.bar(x - width, type1, width, label='Type1', color=plot_style_utils.CAT_PALETTE[0])
ax.bar(x, type2, width, label='Type2', color=plot_style_utils.CAT_PALETTE[1])
ax.bar(x + width, type3, width, label='Type3', color=plot_style_utils.CAT_PALETTE[2])

ax.grid(True, color='0.6', linestyle='--', linewidth=1)
ax.set_xlabel("Class")
ax.set_ylabel("Values")
ax.set_ylim(0, 7.5)

ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(ncol=3, loc='upper center', frameon=False, handlelength=1.5, bbox_to_anchor=(0.5, 1.2))
plot_style_utils.save_for_pub(fig=fig, path="figures/barplot_grouped", include_vector=False)

# %% [markdown]
# ## Stacked barchart

# %%
import numpy as np
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

labels = ['A', 'B', 'C', 'D', 'E']
type1 = np.array([3, 4, 2, 5, 3])
type2 = np.array([4, 3, 4, 6, 7])
type3 = np.array([2, 5, 6, 3, 4])

x = np.arange(len(labels))  # the label locations

width = 0.25  # the width of the bars
ax.bar(labels, type1, width, label='Type1', color=plot_style_utils.CAT_PALETTE[0])
ax.bar(labels, type2, width, label='Type2', color=plot_style_utils.CAT_PALETTE[1], bottom=type1)
ax.bar(labels, type3, width, label='Type3', color=plot_style_utils.CAT_PALETTE[2], bottom=type1+type2)

ax.grid(True, color='0.6', linestyle='--', linewidth=1)
ax.set_xlabel("Class")
ax.set_ylabel("Values")
ax.set_ylim(0, 15)

ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(ncol=3, loc='upper center', frameon=False, handlelength=1.5, bbox_to_anchor=(0.5, 1.2))
plot_style_utils.save_for_pub(fig=fig, path="figures/barplot_stacked", include_vector=False)

# %% [markdown]
# ## Percent stacked barchart

# %%
import numpy as np
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.prettify_ax(ax)

labels = ['A', 'B', 'C', 'D', 'E']
type1 = np.array([3, 4, 2, 5, 3])
type2 = np.array([4, 3, 4, 6, 7])
type3 = np.array([2, 5, 6, 3, 4])

all_data = np.array([type1, type2, type3])
sums = all_data.sum(axis=0)
bar_labels = np.array([f'Type{i+1}' for i in range(len(all_data))])

bottom_y = np.zeros(len(labels))
for i, (data, b_label) in enumerate(zip(all_data, bar_labels)):
    y = data/sums
    ax.bar(labels, y, label=b_label, color=plot_style_utils.CAT_PALETTE[i], bottom=bottom_y)
    bottom_y += y

for c in ax.containers:
    ax.bar_label(c, label_type='center', labels=[f'{100*x:.1f}' for x in c.datavalues], color='w', fontsize=14)

ax.grid(True, color='0.6', linestyle='--', linewidth=1)
ax.set_xlabel("Class")
ax.set_ylabel("Values")
ax.set_ylim(0, 1.0)

ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(ncol=3, loc='upper center', frameon=False, handlelength=1.5, bbox_to_anchor=(0.5, 1.2))
plot_style_utils.save_for_pub(fig=fig, path="figures/barplot_percent_stacked", include_vector=False)

# %% [markdown]
# ## Grouped barchart with catplot

# %%
import seaborn as sns
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")

penguins = sns.load_dataset("penguins")

g = sns.catplot(data=penguins, kind="bar", x="species", y="body_mass_g", hue="sex",
                errorbar="sd", height=6, palette=plot_style_utils.CAT_PALETTE[:2], legend_out=False)

g.set_axis_labels("", "Body mass (g)")
g._legend.remove()
g.fig.set_size_inches(6, 4)
g.fig.legend(loc='upper center', ncol=2, frameon=False, bbox_to_anchor=(0.5, 1.1)) 

g.ax.grid(True, color='0.6', linestyle='--', linewidth=1)
g.ax.set_ylim(0, 6500)
plot_style_utils.save_for_pub(fig=fig, path="figures/barplot_cat_err", include_vector=False)

# %% [markdown]
# ## Grouped barchart with data points

# %%
import seaborn as sns
import plot_style_utils

plot_style_utils.set_pub_plot_context(context="talk")

penguins = sns.load_dataset("penguins")

g = sns.catplot(data=penguins, kind="bar", x="species", y="body_mass_g", hue="sex",
                errorbar="sd", height=6, palette=plot_style_utils.CAT_PALETTE[:2], legend_out=False)

sns.stripplot(data=penguins, x="species", y="body_mass_g", hue="sex", dodge=True, ax=g.ax, edgecolor='black', linewidth=1, palette=plot_style_utils.CAT_PALETTE[:2], legend=False)

g.set_axis_labels("", "Body mass (g)")
g._legend.remove()
g.fig.set_size_inches(6, 4)
g.fig.legend(loc='upper center', ncol=2, frameon=False, bbox_to_anchor=(0.5, 1.1)) 

g.ax.grid(True, color='0.6', linestyle='--', linewidth=1)
g.ax.set_ylim(0, 6500)
plot_style_utils.save_for_pub(fig=fig, path="figures/barplot_cat_dots", include_vector=False)
